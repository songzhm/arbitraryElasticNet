# %%
import pandas as pd
from datetime import datetime
# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %%
data = pd.read_csv('all_stocks_5yr.csv')

# %%
data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
finalData = data.pivot(index='date', columns='Name', values='close')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-e0f16261d3ca> in <module>()
# ----> 1 finalData = data.pivot(index='date', columns='Name', values='close')
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     407             indexed = self._constructor_sliced(self[values].values,
#     408                                                index=index)
# --> 409     return indexed.unstack(columns)
#     410
#     411
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2897         """
#    2898         from pandas.core.reshape.reshape import unstack
# -> 2899         return unstack(self, level, fill_value)
#    2900
#    2901     # ----------------------------------------------------------------------
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     493         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     494                                fill_value=fill_value,
# --> 495                                constructor=obj._constructor_expanddim)
#     496         return unstacker.get_result()
#     497
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     129
#     130         self._make_sorted_values_labels()
# --> 131         self._make_selectors()
#     132
#     133     def _make_sorted_values_labels(self):
#
# /anaconda3/envs/arbitraryElasticNet/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError('Index contains duplicate entries, '
#     170                              'cannot reshape')
#     171
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
finalData.head()
# Out:
# Name              A     AAPL     ABBV      ABC      ABT      ACN   ADBE  \
# date
# 2013-06-24  28.8730  52.4920  35.2134  49.7430  31.3635  71.0011  43.60
# 2013-06-25  28.9890  52.5037  35.8355  49.6873  31.4891  71.4496  44.37
# 2013-06-26  28.8935  51.9091  36.4659  51.0698  31.9285  71.3599  45.68
# 2013-06-27  29.3984  51.3497  36.2558  51.3203  31.7133  71.9518  45.93
# 2013-06-28  29.1801  51.7083  34.7511  51.8028  31.2828  64.5432  45.56
#
# Name            ADI      ADM      ADP       ADS   ADSK      AEE      AEP  \
# date
# 2013-06-24  38.6916  29.0578  60.8550  169.3494  33.48  27.2106  36.1664
# 2013-06-25  39.1222  29.2696  61.2644  171.2577  34.04  27.7251  36.4486
# 2013-06-26  39.6055  29.6314  61.7183  175.4481  34.64  28.0819  37.0213
# 2013-06-27  39.8692  29.7461  61.7361  177.1302  34.92  28.5300  36.9217
# 2013-06-28  39.5967  29.9226  61.2822  178.0745  33.94  28.5798  37.1708
#
# Name            AES      AET      AFL       AGN      AIG      AIV      AIZ  \
# date
# 2013-06-24   9.7427  58.8486  24.7627  117.6043  39.0078  23.7981  44.4193
# 2013-06-25   9.9648  58.8486  25.2697  118.8956  39.9572  24.5188  44.7969
# 2013-06-26  10.1697  59.6060  25.4654  120.6075  40.2060  24.9427  45.1926
